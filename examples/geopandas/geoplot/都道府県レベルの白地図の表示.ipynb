# %%
#!pip install geopandas
#!pip install geoplot

# %%
# %matplotlib inline

import geopandas
import geoplot

pref_geojson = geopandas.read_file('../../../data/github.com/txslgr/geojson/pref_geojson.geojson')
geoplot.polyplot(pref_geojson, figsize=(20, 10))
# Out:
# <AxesSubplot:>
