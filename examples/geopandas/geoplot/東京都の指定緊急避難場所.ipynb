# %%
# %matplotlib inline

import geopandas
import geoplot

tokyo_geojson = geopandas.read_file('../../../data/uedayou.net/東京都.geojson')
shelter_geojson = geopandas.read_file('../../../data/www.geospatial.jp/指定緊急避難場所データ/13.geojson')
ax = geoplot.pointplot(shelter_geojson, figsize=(20, 10))
geoplot.polyplot(tokyo_geojson, ax=ax)
# Out:
# <AxesSubplot:>
