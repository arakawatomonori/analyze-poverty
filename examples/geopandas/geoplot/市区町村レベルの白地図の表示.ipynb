# %%
# %matplotlib inline

import geopandas
import geoplot

city_geojson = geopandas.read_file('../../../data/github.com/txslgr/geojson/city_geojson.geojson')
geoplot.polyplot(city_geojson, figsize=(20, 10))
# Out:
# <AxesSubplot:>
