# %%
import pandas as pd
import japanize_matplotlib
ttf_path = japanize_matplotlib.get_font_ttf_path()

df = pd.read_csv('../data/app.powerbi.com/2020/生活保護世帯と大学進学率関係.csv')
df
# Out:
#    都道府県名  都道府県コード  生活保護世帯進学率(%)  全世帯進学率(%)
# 0    北海道        1          36.2       68.1
# 1    青森県        2          31.0       62.4
# 2    岩手県        3          28.4       65.1
# 3    宮城県        4          32.2       68.8
# 4    秋田県        5          28.0       62.7
# 5    山形県        6          21.1       66.3
# 6    福島県        7          16.1       64.2
# 7    茨城県        8          30.0       65.2
# 8    栃木県        9          30.8       69.8
# 9    群馬県       10          32.5       73.7
# 10   埼玉県       11          37.5       78.4
# 11   千葉県       12          38.1       77.2
# 12   東京都       13          43.0       82.7
# 13  神奈川県       14          38.3       78.9
# 14   新潟県       15          43.6       74.2
# 15   富山県       16          22.2       71.5
# 16   石川県       17          16.0       71.7
# 17   福井県       18          33.3       71.5
# 18   山梨県       19          34.5       69.8
# 19   長野県       20          11.1       72.4
# 20   岐阜県       21          25.0       71.0
# ...

# %%
df.plot.scatter(x='生活保護世帯進学率(%)', y='全世帯進学率(%)')
# Out:
# <AxesSubplot:xlabel='生活保護世帯進学率(%)', ylabel='全世帯進学率(%)'>
